# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoneKris/KGS-Data-Analytics-Portfolio/blob/main/hotel_evidence13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
hotel_evidnece = files.upload()
# Out:
#      <input type="file" id="files-216e801e-f589-4b09-aa9d-55a7a3daa26b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-216e801e-f589-4b09-aa9d-55a7a3daa26b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hotel_evidence (1).csv to hotel_evidence (1).csv

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("hotel_evidence (1).csv")
print(df.head(5))
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel          0.0      342.0             2015.0               July
# 1  Resort Hotel          0.0      737.0             2015.0               July
# 2  Resort Hotel          0.0        7.0             2015.0               July
# 3  Resort Hotel          0.0       13.0             2015.0               July
# 4  Resort Hotel          0.0       14.0             2015.0               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                      27.0                        1.0
# 1                      27.0                        1.0
# 2                      27.0                        1.0
# 3                      27.0                        1.0
# 4                      27.0                        1.0
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                      0.0                   0.0     2.0  ...      NaN
# ...

# %%
print(df.tail(5))
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel          0.0       23.0             2017.0
# 119386  City Hotel          0.0      102.0             2017.0
# 119387  City Hotel          0.0       34.0             2017.0
# 119388  City Hotel          0.0      109.0             2017.0
# 119389  City Hotel          0.0      205.0             2017.0
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                      35.0
# 119386             August                      35.0
# 119387             August                      35.0
# 119388             August                      35.0
# 119389             August                      35.0
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                       30.0                      2.0
# 119386                       31.0                      2.0
# 119387                       31.0                      2.0
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                       float64
# lead_time                         float64
# arrival_date_year                 float64
# arrival_date_month                 object
# arrival_date_week_number          float64
# arrival_date_day_of_month         float64
# stays_in_weekend_nights           float64
# stays_in_week_nights              float64
# adults                            float64
# children                          float64
# babies                            float64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                 float64
# previous_cancellations            float64
# previous_bookings_not_canceled    float64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                   float64
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'booking_number',
#        'total_charges'],
#       dtype='object')

# %%
df.loc[119385]
# Out:
# hotel                                City Hotel
# is_canceled                                 0.0
# lead_time                                  23.0
# arrival_date_year                        2017.0
# arrival_date_month                       August
# arrival_date_week_number                   35.0
# arrival_date_day_of_month                  30.0
# stays_in_weekend_nights                     2.0
# stays_in_week_nights                        5.0
# adults                                      2.0
# children                                    0.0
# babies                                      0.0
# meal                                         BB
# country                                     BEL
# market_segment                    Offline TA/TO
# distribution_channel                      TA/TO
# is_repeated_guest                           0.0
# previous_cancellations                      0.0
# previous_bookings_not_canceled              0.0
# reserved_room_type                            A
# ...

# %%
df.insert(loc = 34, column = 'is_false', value = 0)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'booking_number',
#        'total_charges', 'is_false'],
#       dtype='object')

# %%
df['is_false'].describe()
# Out:
# count    119390.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: is_false, dtype: float64

# %%
df.count()
# Out:
# hotel                             119389
# is_canceled                       119389
# lead_time                         119389
# arrival_date_year                 119389
# arrival_date_month                119389
# arrival_date_week_number          119389
# arrival_date_day_of_month         119389
# stays_in_weekend_nights           119389
# stays_in_week_nights              119389
# adults                            119389
# children                          119385
# babies                            119389
# meal                              119389
# country                           118901
# market_segment                    119389
# distribution_channel              119389
# is_repeated_guest                 119389
# previous_cancellations            119389
# previous_bookings_not_canceled    119389
# reserved_room_type                119389
# assigned_room_type                119389
# booking_changes                   119389
# deposit_type                      119389
# ...

# %%
from scipy import stats

# %%
df['booking_number'].describe()
# Out:
# count    1.193890e+05
# mean     1.059769e+06
# std      4.309612e+04
# min      1.000000e+06
# 25%      1.029848e+06
# 50%      1.059695e+06
# 75%      1.089542e+06
# max      9.999999e+06
# Name: booking_number, dtype: float64

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119389.000000  119389.000000      119389.000000
# mean        0.370419     104.012187        2016.156564
# std         0.482919     106.863213           0.707471
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119389.000000              119389.000000
# mean                  27.165384                  15.798340
# std                   13.605753                   8.780905
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.isna().sum()
# Out:
# hotel                                  1
# is_canceled                            1
# lead_time                              1
# arrival_date_year                      1
# arrival_date_month                     1
# arrival_date_week_number               1
# arrival_date_day_of_month              1
# stays_in_weekend_nights                1
# stays_in_week_nights                   1
# adults                                 1
# children                               5
# babies                                 1
# meal                                   1
# country                              489
# market_segment                         1
# distribution_channel                   1
# is_repeated_guest                      1
# previous_cancellations                 1
# previous_bookings_not_canceled         1
# reserved_room_type                     1
# assigned_room_type                     1
# booking_changes                        1
# deposit_type                           1
# ...

# %%
df.loc[:,['booking_number', 'is_false']]
# Out:
#         booking_number  is_false
# 0            1000000.0         0
# 1            1000001.0         0
# 2            1000002.0         0
# 3            1000003.0         0
# 4            1000004.0         0
# ...                ...       ...
# 119385       9999999.0         0
# 119386       1119386.0         0
# 119387       1119387.0         0
# 119388       1119388.0         0
# 119389       1119389.0         0
#
# [119390 rows x 2 columns]

# %%
df.loc[df['is_false'] == 1, 'is_false'] = 1

# %%
df.loc[:,['booking_number', 'is_false']]
# Out:
#         booking_number  is_false
# 0            1000000.0         0
# 1            1000001.0         0
# 2            1000002.0         0
# 3            1000003.0         0
# 4            1000004.0         0
# ...                ...       ...
# 119385       9999999.0         0
# 119386       1119386.0         0
# 119387       1119387.0         0
# 119388       1119388.0         0
# 119389       1119389.0         0
#
# [119390 rows x 2 columns]

# %%
df['arrival_date_week_number'].describe()
# Out:
# count    119389.000000
# mean         27.165384
# std          13.605753
# min           1.000000
# 25%          16.000000
# 50%          28.000000
# 75%          38.000000
# max          75.000000
# Name: arrival_date_week_number, dtype: float64

# %%
from pandas.core.algorithms import value_counts
df.loc[:,['arrival_date_week_number','booking_number']], value_counts('values')
# Out:
# (        arrival_date_week_number  booking_number
#  0                           27.0       1000000.0
#  1                           27.0       1000001.0
#  2                           27.0       1000002.0
#  3                           27.0       1000003.0
#  4                           27.0       1000004.0
#  ...                          ...             ...
#  119385                      35.0       9999999.0
#  119386                      35.0       1119386.0
#  119387                      35.0       1119387.0
#  119388                      35.0       1119388.0
#  119389                      35.0       1119389.0
#
#  [119390 rows x 2 columns], values    6
#  dtype: int64)

# %%
df.loc[df['booking_number'] > 1119389, 'is_false'] = 1

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119389.000000  119389.000000      119389.000000
# mean        0.370419     104.012187        2016.156564
# std         0.482919     106.863213           0.707471
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119389.000000              119389.000000
# mean                  27.165384                  15.798340
# std                   13.605753                   8.780905
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
var_columns = df.filter
