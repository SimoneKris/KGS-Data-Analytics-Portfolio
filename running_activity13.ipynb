# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoneKris/KGS-Data-Analytics-Portfolio/blob/main/running_activity13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7e51512c-cb58-412c-9b68-649e20d0b94a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e51512c-cb58-412c-9b68-649e20d0b94a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving activity_log.csv to activity_log.csv

# %%
df = pd.read_csv('activity_log.csv')

# %%
df.columns
# Out:
# Index(['Activity Type', 'Date', 'Title', 'Distance', 'Calories', 'Time',
#        'Avg HR', 'Max HR', 'Avg Run Cadence', 'Max Run Cadence', 'Avg Pace',
#        'Best Pace', 'Elev Gain', 'Elev Loss', 'Avg Stride Length',
#        'Best Lap Time', 'Number of Laps'],
#       dtype='object')

# %%
df.head(15)
# Out:
#    Activity Type           Date                Title  Distance Calories  \
# 0        Running   7/15/20 9:41  Cherry Hill Running      6.00      530
# 1        Running  7/14/20 17:45  Cherry Hill Running      6.50      587
# 2        Running  7/13/20 18:57  Cherry Hill Running      5.01      392
# 3        Running  7/12/20 18:44  Cherry Hill Running      7.01      633
# 4        Running  7/11/20 19:35  Cherry Hill Running      5.19      419
# 5        Running  7/10/20 17:54   Ocean City Running      6.51      539
# 6        Running   7/9/20 19:02   Ocean City Running      5.01      448
# 7        Running   7/8/20 18:13   Ocean City Running      5.00      458
# 8        Running    7/6/20 9:43   Ocean City Running      6.00      542
# 9        Running   7/5/20 18:08   Ocean City Running      3.11      240
# 10       Running    7/4/20 7:56   Ocean City Running      5.52      396
# 11       Running   7/3/20 18:16   Ocean City Running      5.00      466
# ...

# %%
df.tail(15)
# Out:
#     Activity Type           Date              Title  Distance Calories  \
# 674       Running  6/15/18 18:38  Baltimore Running      7.95      672
# 675       Running  6/14/18 19:01  Baltimore Running      8.00      718
# 676       Running  6/13/18 18:16  Baltimore Running      8.49      869
# 677       Running  6/12/18 18:44  Baltimore Running      7.96      613
# 678       Running  6/11/18 18:28  Baltimore Running      6.46      548
# 679       Running   6/9/18 15:50  Baltimore Running      6.99      648
# 680       Running   6/8/18 18:15  Baltimore Running      7.00      673
# 681       Running   6/7/18 18:16  Baltimore Running      6.00      553
# 682       Running   6/5/18 18:36  Baltimore Running      5.20      439
# 683       Running   6/4/18 18:41  Baltimore Running      6.03      523
# 684       Running   6/3/18 18:09  Baltimore Running      7.96      808
# 685       Running   6/1/18 18:37  Baltimore Running      6.03      575
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_all = df.dropna()

# %%
df.dtypes
# Out:
# Activity Type         object
# Date                  object
# Title                 object
# Distance             float64
# Calories              object
# Time                  object
# Avg HR                object
# Max HR                object
# Avg Run Cadence       object
# Max Run Cadence       object
# Avg Pace              object
# Best Pace             object
# Elev Gain             object
# Elev Loss             object
# Avg Stride Length    float64
# Best Lap Time         object
# Number of Laps         int64
# dtype: object

# %%
df.rename(columns={"Activity Type": "activity_type", "Date": "date", "Title": "location", "Distance": "distance", "Calories": "calories", "Time": "time", "Avg HR": "avg_hr",
                   "Max HR": "max_hr", "Avg Run Cadence": "avg_run_cadence", "Max Run Cadence": "max_run_cadence", "Avg Pace": "avg_pace", "Best Pace": "best_pace", "Elev Gain": "elev_gain",
                   "Avg Stride Length": "avg_stride_length", "Best Lap Time": "best_lap_time", "Number of Laps": "number_of_laps"})
# Out:
#     activity_type           date             location  distance calories  \
# 0         Running   7/15/20 9:41  Cherry Hill Running      6.00      530
# 1         Running  7/14/20 17:45  Cherry Hill Running      6.50      587
# 2         Running  7/13/20 18:57  Cherry Hill Running      5.01      392
# 3         Running  7/12/20 18:44  Cherry Hill Running      7.01      633
# 4         Running  7/11/20 19:35  Cherry Hill Running      5.19      419
# ..            ...            ...                  ...       ...      ...
# 684       Running   6/3/18 18:09    Baltimore Running      7.96      808
# 685       Running   6/1/18 18:37    Baltimore Running      6.03      575
# 686       Running  5/31/18 18:37    Baltimore Running      5.98      566
# 687       Running  5/30/18 18:30    Baltimore Running      4.15      383
# 688       Running  5/29/18 18:53    Baltimore Running      4.02      314
#
#         time avg_hr max_hr avg_run_cadence max_run_cadence avg_pace best_pace  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import timeit

# %%
activity_log = sns.load_dataset(df.avg_stride_length)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-ae56a656a017> in <module>()
# ----> 1 activity_log = sns.load_dataset(df.avg_stride_length)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'avg_stride_length'

# %%
df_activity_log.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-0a73cf883264> in <module>()
# ----> 1 df_activity_log.describe()
#
# NameError: name 'df_activity_log' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot([distance = int, time = h,m,s])
plt.ylabel('running')
plt.show()
# Out:
#   File "<ipython-input-62-6b24438fb9c5>", line 2
#     plt.plot([distance = int, time = h,m,s])
#                        ^
# SyntaxError: invalid syntax

# %%
_, ax = plt.subplots(figsize=(10,8))
sns.set_context('notebook')
sns.scatterplot(data = df, x = 'distance', y = 'time', hue = 'miles', palette = 'tab10')
plt.xlabel('distance (mile)')
plt.ylabel('time' (h,m,s))
plt.title('distance vs. time')
plt.legend(title = 'Running')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-a98b973b82e6> in <module>()
#       1 _, ax = plt.subplots(figsize=(10,8))
#       2 sns.set_context('notebook')
# ----> 3 sns.scatterplot(data = df, x = 'distance', y = 'time', hue = 'miles', palette = 'tab10')
#       4 plt.xlabel('distance (mile)')
#       5 plt.ylabel('time' (h,m,s))
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
