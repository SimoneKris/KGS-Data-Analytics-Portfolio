# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoneKris/KGS-Data-Analytics-Portfolio/blob/main/impress_your_date.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Access the Cocktail API

# %%
import json
import requests
r = requests.get('http://www.thecocktaildb.com/api/json/v1/1/search.php?s=margarita')
parsed = json.loads(r.text)
print(json.dumps(parsed, indent=4,sort_keys=True))
# import libraries
# using the request libary, call the API
# change the response you get into text, than convert to json
# set the formatting of the json text and print
# Out:
# {
#     "drinks": [
#         {
#             "dateModified": "2015-08-18 14:42:59",
#             "idDrink": "11007",
#             "strAlcoholic": "Alcoholic",
#             "strCategory": "Ordinary Drink",
#             "strCreativeCommonsConfirmed": "Yes",
#             "strDrink": "Margarita",
#             "strDrinkAlternate": null,
#             "strDrinkThumb": "https://www.thecocktaildb.com/images/media/drink/5noda61589575158.jpg",
#             "strGlass": "Cocktail glass",
#             "strIBA": "Contemporary Classics",
#             "strImageAttribution": "Cocktailmarler",
#             "strImageSource": "https://commons.wikimedia.org/wiki/File:Klassiche_Margarita.jpg",
#             "strIngredient1": "Tequila",
#             "strIngredient10": null,
#             "strIngredient11": null,
#             "strIngredient12": null,
#             "strIngredient13": null,
#             "strIngredient14": null,
#             "strIngredient15": null,
# ...
