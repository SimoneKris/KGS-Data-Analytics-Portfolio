# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoneKris/KGS-Data-Analytics-Portfolio/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
bird_df = files.upload()
# Out:
#      <input type="file" id="files-41a1e5bd-4db0-4b0e-a9c1-0fcc19561b49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41a1e5bd-4db0-4b0e-a9c1-0fcc19561b49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bird_tracking.csv to bird_tracking.csv

# %%
import pandas as pd
import numpy as np

# %%
bird_df =pd.read_csv('bird_tracking.csv')

# %%
bird_df.head()
# Out:
#    id  altitude        date_time  device_info_serial   direction  latitude  \
# 0   1        71  8/14/2013 19:18                 851 -150.469753   49.4199
# 1   1        71  8/14/2013 19:18                 851 -150.469753   49.4199
# 2   2        73  8/14/2013 20:47                 851   32.769360   49.4204
# 3   2        73  8/14/2013 20:47                 851   32.769360   49.4204
# 4   3        54  8/14/2013 21:47                 851  -46.344478   49.4204
#
#    longitude nearest_city country  speed_2d  avg_temp
# 0    2.12073        PARIS  FRANCE  0.150000      63.5
# 1    2.12073        PARIS  FRANCE  0.150000      63.5
# 2    2.12086        PARIS  FRANCE  0.310161      63.5
# 3    2.12086        PARIS  FRANCE  0.310161      63.5
# 4    2.12084        PARIS  FRANCE  2.904772      63.5

# %%
bird_df.describe()
# Out:
#                  id      altitude  device_info_serial     direction  \
# count  19998.000000  19998.000000        19998.000000  19860.000000
# mean    5001.702170     51.254725          849.368737     -6.298123
# std     2889.444616    131.633338           12.794659    102.738950
# min        1.000000   -668.000000          833.000000   -179.985721
# 25%     2500.250000      2.000000          833.000000    -91.342279
# 50%     5000.000000     14.000000          851.000000    -12.185866
# 75%     7499.750000     87.000000          864.000000     80.329862
# max     9999.000000   5448.000000          864.000000    180.000000
#
#            latitude     longitude      speed_2d      avg_temp
# count  19998.000000  19998.000000  19860.000000  19998.000000
# mean      30.438638     -8.821899      2.527014     64.139594
# std       14.852786      8.517287      3.571778     16.342918
# min       12.358400    -17.624600      0.000000    -99.000000
# ...

# %%
bird_df.shape
# Out:
# (19998, 11)

# %%
bird_df.columns
# Out:
# Index(['id', 'altitude', 'date_time', 'device_info_serial', 'direction',
#        'latitude', 'longitude', 'nearest_city', 'country', 'speed_2d',
#        'avg_temp'],
#       dtype='object')

# %%
bird_df.isnull()
# Out:
#           id  altitude  date_time  device_info_serial  direction  latitude  \
# 0      False     False      False               False      False     False
# 1      False     False      False               False      False     False
# 2      False     False      False               False      False     False
# 3      False     False      False               False      False     False
# 4      False     False      False               False      False     False
# ...      ...       ...        ...                 ...        ...       ...
# 19993  False     False      False               False      False     False
# 19994  False     False      False               False      False     False
# 19995  False     False      False               False      False     False
# 19996  False     False      False               False      False     False
# 19997  False     False      False               False      False     False
#
#        longitude  nearest_city  country  speed_2d  avg_temp
# ...

# %%
bird_df.isnull().sum()
# Out:
# id                      0
# altitude                0
# date_time               0
# device_info_serial      0
# direction             138
# latitude                0
# longitude               0
# nearest_city            0
# country                 0
# speed_2d              138
# avg_temp                0
# dtype: int64

# %%
bird_df.dropna(inplace=True)

# %%
bird_df.head()
# Out:
#    id  altitude        date_time  device_info_serial   direction  latitude  \
# 0   1        71  8/14/2013 19:18                 851 -150.469753   49.4199
# 1   1        71  8/14/2013 19:18                 851 -150.469753   49.4199
# 2   2        73  8/14/2013 20:47                 851   32.769360   49.4204
# 3   2        73  8/14/2013 20:47                 851   32.769360   49.4204
# 4   3        54  8/14/2013 21:47                 851  -46.344478   49.4204
#
#    longitude nearest_city country  speed_2d  avg_temp
# 0    2.12073        PARIS  FRANCE  0.150000      63.5
# 1    2.12073        PARIS  FRANCE  0.150000      63.5
# 2    2.12086        PARIS  FRANCE  0.310161      63.5
# 3    2.12086        PARIS  FRANCE  0.310161      63.5
# 4    2.12084        PARIS  FRANCE  2.904772      63.5
